# %% [markdown]
# <a href="https://colab.research.google.com/github/mohammadshehroz123/Artificial-Intelligence-Assignment-3-Regression/blob/main/QuadraticModel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
def readDataFromCSVFile (file_name):
  data = pd.read_csv(file_name)
  return data

# %%
TrainFile = readDataFromCSVFile('trainRegression.csv')
TestFile = readDataFromCSVFile('testRegression.csv')

# %%
#reading data using helper function 

trainX_data = TrainFile['X']
trainY_data = TrainFile['R']

testX_data = TestFile['X']
testY_data = TestFile['R']

# %%
#Converting data above in the form of Matrices (using Numpy)

X_data_train = np.array(trainX_data)
Y_data_train = np.array(trainY_data)

X_data_test = np.array(testX_data)
Y_data_test = np.array(testY_data)

# %%
# Plot Training Data
plt.figure(1)
plt.plot(X_data_train,Y_data_train)

# %%
# Plot Testing Data
plt.figure(2)
plt.plot(X_data_test,Y_data_test)

# %%
#Main Work of Quadratic Regression

A = np.arange(9).reshape(3,3)
B = np.arange(3)
X = np.arange(3)

# %%
A[0][0] = X_data_train.shape[0]
A[0][1] = np.sum(X_data_train)
A[0][2] = np.sum(X_data_train*X_data_train)
A[1][0] = A[0][1]
A[1][1] = A[0][2]
A[1][2] = np.sum(X_data_train * X_data_train * X_data_train)
A[2][0] = A[1][1]
A[2][1] = A[1][2]
A[2][2] = np.sum(X_data_train * X_data_train * X_data_train * X_data_train)
B[0] = np.sum(Y_data_train)
B[1] = np.sum(Y_data_train * X_data_train)
B[2] = np.sum(Y_data_train * X_data_train * X_data_train)


inverse_A = np.linalg.inv(A)
X = np.dot(inverse_A,B)

# %%
M1 = X[2]
M = X[1]
C = X[0]

#Hypothesis Function
predictions = np.array(C + M * X_data_test + M1 * X_data_test * X_data_test)

# %%
FinalPlot = plt.figure(2)
print("Quaratic Regression Model Plotting")
plt.plot(X_data_test, Y_data_test)
plt.plot(X_data_test, predictions)
# Out:
# Quaratic Regression Model Plotting

# %%
#calculating mean square
mean_square = (np.sum((predictions - Y_data_test) * (predictions - Y_data_test)) / (2 * X_data_test.shape[0]))
print("Mean Square :", mean_square)
# Out:
# Mean Square : 0.16062333860543732
